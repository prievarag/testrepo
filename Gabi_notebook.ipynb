# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Prievara Gabriella**
# controller

# %% [markdown]
# *I am interested in Data Science because currently I work as controller, and with DS knowledge I can make better predictions as well better understanding of the data*

# %% [markdown]
# ### My code will do a simple calculation task. Only for practice.

# %%
1+1
# Out:
# 2

# %% [markdown]
# ~~Scratch this.~~
#
# - first element
# - second element
# - third element
#
# 1. Hello
# 2. World
# 3. By
